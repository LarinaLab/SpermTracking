# %%
import pandas as pd
import numpy as np

# %%
def VCL(df):
  df[['dx','dy','dz']]=df[['Position X','Position Y','Position Z']].diff()
  df['vcl']=(df['dx']**2+df['dy']**2+df['dz']**2)**0.5/0.9
  return df['vcl'].mean()
